# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sms
df = pd.read_csv('penguins-data.csv')
df.head(10)
# Out:
#    Unnamed: 0 species     island  bill_length_mm  bill_depth_mm  \
# 0           0  Adelie  Torgersen            39.1           18.7
# 1           1  Adelie  Torgersen            39.5           17.4
# 2           2  Adelie  Torgersen            40.3           18.0
# 3           4  Adelie  Torgersen            36.7           19.3
# 4           5  Adelie  Torgersen            39.3           20.6
# 5           6  Adelie  Torgersen            38.9           17.8
# 6           7  Adelie  Torgersen            39.2           19.6
# 7          12  Adelie  Torgersen            41.1           17.6
# 8          13  Adelie  Torgersen            38.6           21.2
# 9          14  Adelie  Torgersen            34.6           21.1
#
#    flipper_length_mm  body_mass_g     sex
# 0                181         3750    MALE
# 1                186         3800  FEMALE
# 2                195         3250  FEMALE
# 3                193         3450  FEMALE
# 4                190         3650    MALE
# 5                181         3625  FEMALE
# 6                195         4675    MALE
# 7                182         3200  FEMALE
# 8                191         3800    MALE
# 9                198         4400    MALE

# %%
print("số lượng chim cách cụt của mỗi loài")
df['species'].value_counts()
# Out:
# số lượng chim cách cụt của mỗi loài
# species
# Adelie       146
# Gentoo       119
# Chinstrap     68
# Name: count, dtype: int64

# %%
print("số lượng chim cách cụt của đảo")
df['island'].value_counts()
# Out:
# số lượng chim cách cụt của đảo
# island
# Biscoe       163
# Dream        123
# Torgersen     47
# Name: count, dtype: int64

# %%
print("do dai mo")
df['bill_length_mm'].describe()
# Out:
# do dai mo
# count    333.000000
# mean      43.992793
# std        5.468668
# min       32.100000
# 25%       39.500000
# 50%       44.500000
# 75%       48.600000
# max       59.600000
# Name: bill_length_mm, dtype: float64

# %%
print("do sau mo")
df['bill_depth_mm'].describe()
# Out:
# do sau mo
# count    333.000000
# mean      17.164865
# std        1.969235
# min       13.100000
# 25%       15.600000
# 50%       17.300000
# 75%       18.700000
# max       21.500000
# Name: bill_depth_mm, dtype: float64

# %%
print('do dai canh')
df['flipper_length_mm'].describe()
# Out:
# do dai canh
# count    333.000000
# mean     200.966967
# std       14.015765
# min      172.000000
# 25%      190.000000
# 50%      197.000000
# 75%      213.000000
# max      231.000000
# Name: flipper_length_mm, dtype: float64

# %%
print("trong luong")
df['body_mass_g'].describe()
# Out:
# trong luong
# count     333.000000
# mean     4207.057057
# std       805.215802
# min      2700.000000
# 25%      3550.000000
# 50%      4050.000000
# 75%      4775.000000
# max      6300.000000
# Name: body_mass_g, dtype: float64

# %%
print("mean")
x = np.array(['độ dài mõ', 'độ sâu mõ', 'độ dài cánh', 'trọng lượng'])
y = np.array([43.992793, 17.164865,200.966967,  4207.057057 ])
plt.bar(x,y)
plt.show()
# Out:
# mean

# %%
# nhận xét
count bằng nhau
mean của trọng lượng lớn nhất
mean của độ dài cánh nhỏ nhất
sdt của trọng lượng lớn nhất
sdt của độ dài mõ nhỏ nhất
nếu nhìn qua có thể thấy trọng lớn chiếm phần lớn nhất

# %%
print("độ lệch chuẩn")
x = np.array(['độ dài mõ', 'độ sâu mõ', 'độ dài cánh', 'trọng lượng'])
y = np.array([5.468668,1.969235,  14.015765, 805.215802 ])
plt.bar(x,y)
plt.show()
# Out:
# độ lệch chuẩn

# %%
print("count")
x = np.array(['độ dài mõ', 'độ sâu mõ', 'độ dài cánh', 'trọng lượng'])
y = np.array([333.000000, 333.000000, 333.000000, 333.000000])
plt.bar(x,y)
plt.show()
# Out:
# count

# %%
# độ lệch chuẩn
# y = np.array([35, 25, 25, 15])
# mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

# plt.pie(y, labels = mylabels)
# plt.show()


# độ lệch chuẩn
y = np.array([5.468668,  1.969235, 14.015765, 805.215802])
mylabels = ['độ dài mõ', "độ sâu mõ", 'độ dài cánh', 'trọng lượng']
plt.pie(y, labels= mylabels )
plt.show()

# %%
import seaborn as sns
sns.boxplot(data = df, x = 'bill_length_mm')
# Out:
# <Axes: xlabel='bill_length_mm'>

# %%
# sns.boxplot(data = df, x='bill_depth_mm')
# Out:
# <Axes: xlabel='bill_depth_mm'>

# %%
sns.displot(data = df, x='flipper_length_mm')
# Out:
# e:\annacoda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.histplot(data = df['flipper_length_mm'])
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='Count'>

# %%
# sns.displot(data=df, x='island', col='sex')
# Out:
# e:\annacoda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.boxplot(data = df, y='body_mass_g')
# Out:
# <Axes: ylabel='body_mass_g'>

# %%
df[['island',	'bill_length_mm','bill_depth_mm','flipper_length_mm' , 'body_mass_g']].groupby(['island']).mean()
# Out:
#            bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# island
# Biscoe          45.248466      15.907362         209.558282  4719.171779
# Dream           44.221951      18.339837         193.186992  3718.902439
# Torgersen       39.038298      18.451064         191.531915  3708.510638
